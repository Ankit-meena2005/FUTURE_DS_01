# %% [markdown]
# # 📊 Business Sales Performance Analytics
# ## Data Science & Analytics – Task 1 (2026)
# ### Intern: Ankit Meena

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Dataset.csv')
df.head()

# %%
df.info()
df.describe()

# %%
df.drop_duplicates(inplace=True)
df['Order Date'] = pd.to_datetime(df['Order Date'])

df.head()

# %%
total_revenue = df['Sales'].sum()
total_profit = df['Profit'].sum()
avg_order_value = df['Sales'].mean()

print('Total Revenue:', total_revenue)
print('Total Profit:', total_profit)
print('Average Order Value:', avg_order_value)

# %%
df['Month'] = df['Order Date'].dt.to_period('M')
monthly_sales = df.groupby('Month')['Sales'].sum()

plt.figure()
monthly_sales.plot()
plt.title('Monthly Revenue Trend')
plt.xlabel('Month')
plt.ylabel('Total Sales')
plt.xticks(rotation=45)
plt.show()

# %%
top_products = df.groupby('Product Name')['Sales'].sum().sort_values(ascending=False).head(5)

plt.figure()
top_products.plot(kind='bar')
plt.title('Top 5 Products by Revenue')
plt.xlabel('Product')
plt.ylabel('Total Sales')
plt.xticks(rotation=45)
plt.show()

# %%
category_sales = df.groupby('Category')['Sales'].sum()

plt.figure()
category_sales.plot(kind='bar')
plt.title('Category-wise Revenue')
plt.xlabel('Category')
plt.ylabel('Total Sales')
plt.show()

# %%
region_sales = df.groupby('Region')['Sales'].sum()

plt.figure()
region_sales.plot(kind='bar')
plt.title('Region-wise Revenue')
plt.xlabel('Region')
plt.ylabel('Total Sales')
plt.show()

# %% [markdown]
# ## 💡 Key Insights
# - Technology category generates the highest revenue.
# - West region contributes maximum sales.
# - Laptop and Smartphone are top-performing products.
# - Revenue shows steady growth during mid-year months.
#
# ## 🚀 Recommendations
# - Focus marketing on high-performing categories.
# - Expand operations in top regions.
# - Promote top-selling products.
# - Improve lower-performing areas with targeted strategies.
